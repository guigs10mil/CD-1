# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats import expon, binom, poisson, gamma

# %%
airplane_crashes = pd.read_csv('Airplane_Crashes_and_Fatalities_Since_1908.csv', sep=",")

# %%
airplane_crashes.head(5)
# Out:
#         ﻿Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %%
print('Linhas: ', airplane_crashes.shape[0], '\nColunas: ', airplane_crashes.shape[1])
# Out:
# Linhas:  5268
# Colunas:  13

# %%
fatalities = airplane_crashes.Fatalities.dropna()
fatalities = fatalities[fatalities > 0]
fatalities.describe()
# Out:
# count    5198.000000
# mean       20.292228
# std        33.316562
# min         1.000000
# 25%         3.000000
# 50%         9.000000
# 75%        23.000000
# max       583.000000
# Name: Fatalities, dtype: float64

# %%
plt.figure(figsize=(12,8))
fatalities.hist(bins=30, normed=True, color='#0A76D5')
plt.axvline(fatalities.median(), lw=1.5, label='Mediana', color='r', ls='dashed')
plt.axvline(fatalities.mean(), lw=1.5, label='Media', color='black', ls='dashed')
plt.title('Fatalidades por acidente de aviao\n')
plt.ylabel('Freq. relativa')
plt.xlabel('Numero de mortes')
plt.legend(loc='best')
plt.axis([0,300,0,0.04])
plt.show()

# %% [markdown]
# O histograma acima pode ter dois tipos de distribuiçãoes, uma <b>exponencial</b> com a base do número entre 0 e 1, e uma outra <b>binomial</b>. Ambas as funções das distribuições são decrescentes.

# %%
mu = fatalities.mean()
sigma = fatalities.std()
x = sorted(fatalities)

k_gamma = 1.2
theta_gamma = fatalities.mean()/k_gamma

plt.figure(figsize=(12,8))
fatalities.hist(bins=50, normed=True, color='#0A76D5')
plt.plot(x, expon.pdf(x, scale=mu), color='red', lw=2, alpha=1, label='Exponencial')
plt.plot(x, gamma.pdf(x, scale=theta_gamma, loc=0, a=k_gamma), color='black', alpha=1, label='Gamma')
plt.title('Fatalidades desde 1908\n')
plt.ylabel('Freq. relativa')
plt.xlabel('Numero de mortes')
plt.legend(loc='best')
plt.axis([0,300,0,0.04])
plt.show()

# %%
plt.figure(figsize=(12,8))
fatalities.hist(bins=30, normed=True, color='#0A76D5')
plt.plot(x, binom.ppf(x, loc=mu, scale=sigma), color='red', lw=2, alpha=0.5, label='pdf')
plt.title('Fatalidades desde 1908\n')
plt.ylabel('Freq. relativa')
plt.xlabel('Numero de mortes')
plt.legend(loc='best')
plt.axis([0,300,0,0.04])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-f894bed9b853> in <module>()
#       1 plt.figure(figsize=(12,8))
#       2 fatalities.hist(bins=30, normed=True, color='#0A76D5')
# ----> 3 plt.plot(x, binom.ppf(x, loc=mu, scale=sigma), color='red', lw=2, alpha=0.5, label='pdf')
#       4 plt.title('Fatalidades desde 1908\n')
#       5 plt.ylabel('Freq. relativa')
#
# C:\Users\4Python\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in ppf(self, q, *args, **kwds)
#    3048
#    3049         """
# -> 3050         args, loc, _ = self._parse_args(*args, **kwds)
#    3051         q, loc = map(asarray, (q, loc))
#    3052         args = tuple(map(asarray, args))
#
# TypeError: _parse_args() got an unexpected keyword argument 'scale'
